# %% [markdown]
# <a href="https://colab.research.google.com/github/Visal-Se/Google-Collab/blob/main/Program_3_Nursery_Rhymes(M_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SAVE A COPY** OF THIS NOTEBOOK TO YOUR OWN DRIVE **BEFORE YOU START**

# %% [markdown]
# Put your full program here - both Part 1 and Part 2 in the same code block!

# %%
def farm(animal, sound):
  print("Old MacDonald had a farm")
  print("e-i-e-i-o")
  print(f"And on that farm he had a {animal} ")
  print("e-i-e-i-o")
  print(f"With a {sound}, {sound} here")
  print(f"And a {sound}, {sound} there")
  print(f"Here a {sound}, there a {sound}")
  print(f"Everywhere a {sound} {sound}")
  print("Old MacDonald had a farm")
  print("e-i-e-i-o")
  print()

def monkeys(number):
  print(f"{number} little monkeys jumping on the bed")
  print("One fell off and bumped his head")
  print("Mama called the doctor, and the doctor said")
  print("\"No more monkeys jumping on the bed!\"")
  print()

def hickory_dickory(time):
  print("Hickory dickory dock")
  print("The mouse ran up the clock ")
  print(f"The clock struck {time}")
  print("The mouse ran down ")
  print("Hickory dickory dock")
  print()

#=====main=====
farm("pig", "oink")
farm("horse", "neigh")
farm("sheep", "baa")
#TODO: call the farm function with a new animal and sound (completed)

monkeys(8)
monkeys(7)
monkeys(6)
#TODO: call the monkeys function with 8 monkeys (completed)

hickory_dickory(1)
hickory_dickory(2)
hickory_dickory(3)
#TODO: call the hickory_dickory function with 3 (completed)

def milk(number):
  print(f"{number} bottles of milk on the wall")
  print(f"{number} bottles of milk")
  print("Take one down and pass it around")
  number_1=(int(number- 1))
  print(f"{number_1} bottles of milk on the wall")
  print()

def hocky_pocky(body_part):
  print(f"You put your {body_part} in")
  print(f"You put your {body_part} out")
  print(f"You put your {body_part} in")
  print("And you shake it all about")
  print("You do the Hokey Pokey")
  print("And you turn yourself about")
  print("That’s what it’s all about!")
  print()

def frogs(number):
  print(f"{number} little speckled frogs")
  print("sitting on a speckled log")
  print("eating the most delicious bugs")
  print("yum, yum")
  print("one jumped into the pool")
  print("where it is nice and cool")
  number_1= int(number-1)
  print(f"now there are {number_1} little speckled frogs!")
  print("rabbit, rabbit")
  print()


#-------MAIN---------
milk(50)
milk(49)
# milk functions (completed)

hocky_pocky("left foot")
hocky_pocky("right foot")
# hocky_pocky functions (completed)

frogs(5)
frogs(4)
# frogs functions (completed)
# Out:
# Old MacDonald had a farm
# e-i-e-i-o
# And on that farm he had a pig
# e-i-e-i-o
# With a oink, oink here
# And a oink, oink there
# Here a oink, there a oink
# Everywhere a oink oink
# Old MacDonald had a farm
# e-i-e-i-o
#
# Old MacDonald had a farm
# e-i-e-i-o
# And on that farm he had a horse
# e-i-e-i-o
# With a neigh, neigh here
# And a neigh, neigh there
# Here a neigh, there a neigh
# Everywhere a neigh neigh
# Old MacDonald had a farm
# e-i-e-i-o
#
# Old MacDonald had a farm
# e-i-e-i-o
# And on that farm he had a sheep
# e-i-e-i-o
# With a baa, baa here
# And a baa, baa there
# Here a baa, there a baa
# Everywhere a baa baa
# Old MacDonald had a farm
# e-i-e-i-o
#
# 8 little monkeys jumping on the bed
# One fell off and bumped his head
# Mama called the doctor, and the doctor said
# "No more monkeys jumping on the bed!"
#
# 7 little monkeys jumping on the bed
# One fell off and bumped his head
# Mama called the doctor, and the doctor said
# ...
